# %% [markdown]
# <a href="https://colab.research.google.com/github/ShadowRaccoon/PrograConcurrente2023C1/blob/main/TP1_Parte3_Python_M1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Python**

# %%
# %%writefile tp1_parte3.py
from multiprocessing import Pipe
import os
import sys
DEFAULT_CHUNK_SIZE = 512
APPEND_BYTES = "ab"
READ_BYTES = "rb"
WRITE_BYTES = "wb"


def validate_args(args):
    if len(args) < 2:
        print("Cantidad incorrecta de argumentos.")
        os._exit(1)

    path = args[1]
    if not os.path.isfile(path):
        print("La ruta al archivo no es valida.")
        os._exit(1)

    size = DEFAULT_CHUNK_SIZE
    if len(args) == 3:
        size = int(args[2])
        if size <= 0:
            print("Tamaño del chunk invalido.")
            os._exit(1)        
    return (path, size)

def recieve_file_data(recieve, chunk_size, file_name):
    # Limpio el archivo si usa el mismo nombre
    open(file_name, WRITE_BYTES).close()
    try:
        chunk = recieve.recv_bytes()
        with open(file_name, APPEND_BYTES) as f:
            while chunk:
                f.write(chunk)
                chunk = recieve.recv_bytes()
    except EOFError:
        recieve.close()

def send_file_data(send, path, chunk_size): 
    with open(path, READ_BYTES) as f:
        data = f.read(chunk_size)
        while data:
            send.send_bytes(data)
            data = f.read(chunk_size)
        f.close()
        send.close()

def main():
    path, chunk_size = validate_args(sys.argv)
    send, recieve = Pipe()
    pid = os.fork()
    if pid < 0:
        print("Error al crear el nuevo proceso")
        os._exit(1)
    if pid:
        # Proceso Hijo que recibe datos
        file_name = "copia_" + os.path.basename(path)
        send.close()
        recieve_file_data(recieve, chunk_size, file_name)
    else:
        # Proceso Padre que envia datos
        recieve.close()
        send_file_data(send, path, chunk_size)    

main()
# Out:
# Overwriting tp1_parte3.py

# %%
# %%writefile archivo.txt
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# 
# Out:
# Overwriting archivo.txt

# %%
# !python3 tp1_parte3.py
# Out:
# Cantidad incorrecta de argumentos.

# %%
# !python3 tp1_parte3.py archivo.txt

# %%
# !ls
# Out:
# archivo.txt  copia_archivo.txt	sample_data  tp1_parte3.py

# %%
# !diff archivo.txt copia_archivo.txt

# %% [markdown]
# Vemos que el comando "diff" devuelve vacio cuando los archivos no tienen diferencias

# %% [markdown]
# Probamos especificando el chunk size

# %%
# !python3 tp1_parte3.py archivo.txt 123

# %%
# !ls
# Out:
# archivo.txt  copia_archivo.txt	sample_data  tp1_parte3.py

# %%
# !diff archivo.txt copia_archivo.txt

# %% [markdown]
# Vemos que el comando "diff" devuelve vacio cuando los archivos no tienen diferencias
